# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ayesha-asif1/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose the Content Refresh Recommendation lane because the dataset contains information such as content age, impressions, click-through rate (CTR), average search position, and update history. These features can help identify pages that may be declining and should be reviewed. The goal is to support SEO and content teams by helping them prioritize which pages to refresh first instead of checking every page manually.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## The Question: Decision, Action, Cost of a Wrong Call
#
# **Decision:** Which webpages should be prioritized for content refresh?
#
# **Unit of analysis:** One webpage.
#
# **Output:** A recommendation or priority score indicating whether a page should be refreshed.
#
# **Who acts on it?** The SEO or content team.
#
# **Action:** Review and update the recommended webpages to improve their search performance.
#
# **Cost of a wrong recommendation:** Refreshing a healthy page wastes time and resources, while missing a truly declining page may result in lower traffic, fewer clicks, and missed opportunities. The model is intended to support decisions, not replace human judgment.
#
# My project will help the content team decide which webpages should be refreshed first based on the available data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick Look at the Data
#
# The starter dataset contains information about webpage performance, including impressions, content age, and update history. The code below loads the dataset and displays real statistics. These numbers help determine whether there is enough variation in the data to support the Content Refresh Recommendation project.

# %%
import os
print(os.listdir("../../data/raw"))
# Out:
# ['content_refresh_anonymized.csv']

# %%
for col in df.columns:
    print(col)
# Out:
# content_id
# client_id
# search_volume
# competition
# competition_level
# cpc
# content_type
# main_intent
# word_count
# char_count
# provider_used
# model_used
# impressions_90d
# clicks_90d
# pageviews_90d
# sessions_90d
# users_90d
# engaged_sessions_90d
# ai_sessions_90d
# scroll_events_90d
# days_with_impressions
# days_with_sessions
# impressions_last_30d
# clicks_last_30d
# sessions_last_30d
# impressions_prev_30d
# clicks_prev_30d
# sessions_prev_30d
# content_age_days
# age_tier
# age_tier_order
# days_since_last_update
# freshness_tier
# word_count_tier
# char_count_tier
# ctr
# avg_position
# engagement_rate
# scroll_rate
# ai_traffic_pct
# impression_tier
# position_tier
# trend_direction
# trend_pct

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))

print("\nTrend direction:")
print(df["trend_direction"].value_counts())

print("\nAverage impressions (90d):")
print(df["impressions_90d"].mean())

print("\nAverage days since last update:")
print(df["days_since_last_update"].mean())
# Out:
# Rows: 30000
# Columns: 44
#
# Trend direction:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average impressions (90d):
# 5200.3663
#
# Average days since last update:
# 46.0983

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project is intended to support decision-making by identifying webpages that may benefit from a content refresh based on observed patterns in the available data. The recommendations are directional and should help prioritize which pages to review first.
#
# This project cannot prove that refreshing a page will increase rankings, clicks, or traffic. It does not predict Google's search algorithm or establish cause-and-effect relationships. Final decisions should always include human review and further evaluation.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
